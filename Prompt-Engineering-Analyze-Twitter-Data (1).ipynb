# %% [markdown]
# # Prompt Engineering: Use OpenAI to Analyze Twitter Data
# This is a simple tutorial teaching prompt engineering basics and analyzing Twitter data with OpenAI large language models (LLM).
# Please purchase an [OpenAI API](https://openai.com/index/openai-api/) and store it in a safe place. This tutorial uses [AWS Secretes Manager](https://aws.amazon.com/secrets-manager/) to store the API keys.

# %% [markdown]
# ## Large Language Model Basics
# LLM repeatable predicts the next world using supervised learning. To predict the following sentence:
#
# `Learning data science in the cloud with AI`
#
# A model needs to learn to predict the following steps:
#
# |Input|Output|
# |:---|---|
# |Learning data science |in |
# |Learning data science in |the |
# |Learning data science in the |cloud |
# |Learning data science in the cloud |with |
# |Learning data science in the cloud with |AI|
#
# To train an LLM model:
# 1. Training a base LLM model on a large amount of training data to predict the next word
# 2. Fine-tune on examples where outputs follow instructions in the input
# 3. Human rates quality of different LLM outputs
# 4. Tune LLM to generate outputs with higher rates using RLHF (Reinforcement learning from human feedback)

# %% [markdown]
# ## Set up OpenAI Models

# %% [markdown]
# Load the API keys with AWS Secrets Manage Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Install Python libraries.
#
# - pymongo: manage the MongoDB database
# - openai: call the OpenAI APIs.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.70.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Downloading openai-1.70.0-py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 29.6 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Installing collected packages: jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.9.0 openai-1.70.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.4 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load the OpenAI API key and define a `openai_help` function.

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

def openai_help(messages, model=model, temperature =temperature ):
    messages = messages
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature

    )
    return response.choices[0].message.content

# %% [markdown]
# Temperature:
# - Low temperature: always choose the most likely response, reliable, predictable responses
# - High temperature: diverse responses, more creative responses
#
# Tokens and Models:
# - LLM predicts tokens, which are commonly occurring sequences of characters.
# - One token is about four characters in English, and 100 tokens are roughly 75 words. Check [token estimate](https://platform.openai.com/tokenizer).
# - Different models can process various amounts of tokens at different performance levels and costs. Check [OpenAI models](https://platform.openai.com/docs/models) for more details.
#
# Roles:
# - system: specify the overall tone or behavior of the assistant
# - user: instruction given to the LLM
# - assistant: LLM responded content, we also can provide content in few-shot promoting or histories of conversations

# %% [markdown]
# A simple example using [gtp-4o](https://platform.openai.com/docs/models/gpt-4o) and temperature 0.

# %%
messages = [{"role": "user", "content": "What is the capital of USA"}]

print(openai_help(messages))
# Out:
# The capital of the United States is Washington, D.C.

# %% [markdown]
# Add a system message asking LLM to act as a high school teacher with different temperatures.

# %%
messages = [
    {"role": "system", "content": "use tone as a high school teacher"},
    {"role": "user", "content": "What is the capital of USA"}
    ]

print(openai_help(messages, temperature = 0.8))
# Out:
# The capital of the United States is Washington, D.C. It's an important city not just because it's the capital, but also because it's home to many iconic landmarks, such as the White House, the U.S. Capitol, and numerous museums and monuments. If you're interested in American history or politics, learning more about Washington, D.C. could be really fascinating!

# %% [markdown]
# Add assistant messages to teach LLM what `##` is.

# %%
messages = [
    {"role": "user", "content": "What is 1##1"},
    {"role": "assistant", "content": "it is 11"},
    {"role": "user", "content": "What is 2##2"},
    {"role": "assistant", "content": "it is 22"},
    {"role": "user", "content": "What is 3##3"},
    ]
print(openai_help(messages))
# Out:
# It is 33.

# %% [markdown]
# ## Prompt Engineering Principles
# - Use delimiters to separate different parts of a prompt to provide clear instructions and prevent prompt injections.
# - Structure outputs in JSON documents or other formats to use the outputs in subsequent steps
# - Few-shot promoting: provide successful examples of a task and then ask the model to perform a similar task.
# - Chain of thought reasoning: request a series of reasoning steps in prompts to help the model achieve correct answers
# - Chain of prompts: split a task into multiple prompts where each prompt can focus on a sub-task at a time and take different actions at different stages. It saves tokens, is easier to test, can involve human input, or use external tools.
# - Interactive process
#   1. Try something first
#   2. Analyses the result, identify errors, and redefine the prompt
#   3. Test the prompts with different datasets

# %% [markdown]
# An example using delimiters, structured output and few-shot promoting:

# %%
delimiter = '###'
sentence1 = 'I love cat.'
sentence2 = 'I love dog.'
messages = [
    {"role": "system", "content": f"""analyze the sentiment in a sentence delimitered by {delimiter},
                                     return the result as a JSON document"""},
    {"role": "user", "content": f"{delimiter}{sentence1}{delimiter}"},
    {"role": "assistant", "content": "{sentiment:positive}"},
    {"role": "user", "content": f"{delimiter}{sentence2}{delimiter}"}
    ]

print(openai_help(messages))
# Out:
# { "sentiment": "positive" }

# %% [markdown]
# ## Analyze Twitter data

# %% [markdown]
# ### Connect to the MongoDB cluster

# %%
import pymongo
from pymongo import MongoClient
mongodb_connect = get_secret('mongodb')['connection_string']

mongo_client = MongoClient(mongodb_connect)
db = mongo_client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("tweet.id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'tweet.id_1'

# %% [markdown]
# ### Extract Tweets

# %%
filter={

    
}
project={
    'tweet.text': 1, 
    'tweet.id': 1
}
#rename the client to mongo_client
result = mongo_client['demo']['tweet_collection'].find(
  filter=filter,
  projection=project
)

# %%
tweet_data = []
for tweet in result:
    tweet_data.append(tweet['tweet']['text'])

# %%
print('Number of tweets: ',len(tweet_data))
# Out:
# Number of tweets:  200

# %% [markdown]
# ### Summarization
# - Analyze election tweets with delimiters
# - Change the size of the summarization
# - Summarize tweets and focus on different perspectives.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter}"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets revolve around various aspects of the upcoming election, with a strong focus on the U.S. political climate. Key themes include concerns about election integrity, with accusations of potential election interference and fraud, particularly involving the Democratic Party. There are discussions about the role of media and misinformation, as well as the influence of dark money in politics. Some tweets highlight specific election-related events, such as court rulings in Georgia and voter registration issues in Pennsylvania. Others mention political figures like Donald Trump, Kamala Harris, and Joe Biden, with debates over their roles and actions. Additionally, there are mentions of election predictions, market reactions, and the importance of voter turnout. Overall, the tweets reflect a highly charged and polarized political environment leading up to the election.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    limit the summary to 20 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets discuss election concerns, misinformation, and predictions, with a focus on Trump, Kamala Harris, and potential election interference.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    focus on how people discuss AI,
                                    limit the summary to 50 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets primarily focus on election-related discussions, with minimal mention of AI. The conversation revolves around election integrity, misinformation, and political strategies. There is a notable absence of AI-related discourse, as the tweets are dominated by political opinions, election predictions, and concerns about potential election interference.

# %% [markdown]
# ### Moderation
# - Iterate each tweet and use the [moeration endpoint](https://platform.openai.com/docs/api-reference/moderations) to identify flagged tweets
# - Print flagged tweets

# %%
def flag_help(tweet):
    response = client.moderations.create(
        model="omni-moderation-latest",
        input=tweet)

    if response.results[0].flagged:
        print('===')
        cat_dict = response.results[0].categories.to_dict()
        for cat in cat_dict.keys():
            if cat_dict.get(cat):
                print (cat)
                print(tweet)

# %%
for tweet in tweet_data:
    flag_help(tweet)
# Out:
# ===
# harassment
# @BretBaier This will be the biggest pillow fight of the election process. She was indeed the Border Czar, she lied to us about the health of President Biden, used tax payer $ to pay for a convicted felons sex change,  no wars when Trump was President and what is her position on the freedom… https://t.co/PEgwpFAM5q
# ===
# harassment
# RT @caslernoel: Never lose sight of what a clownish little man Mike Johnson is and how he ALREADY worked on behalf of Trump’s attempts at o…
# ===
# violence
# RT @democracynow: Uncommitted Co-Founder Abbas Alawieh on U.S. Election &amp; Family in Lebanon Fleeing Israeli Bombs https://t.co/f00eSotc84
# ===
# harassment
# RT @maddenifico: Some of you self-righteous motherfuckers on the left are once again overthinking this. It's as if you faux-prog frauds lea…
# ===
# violence
# RT @ecomarxi: Biden/Harris [during a full year of genocide &amp; overwhelming domestic &amp; international pressure to embargo Israel]: We will NEV…
# ===
# harassment
# @LauraLoomer Their time will be coming to an end soon once Trump wins this election. They will be running and hiding. No more protection from this treasonous administration.
# ===
# violence
# RT @nypost: Israel is ready to strike Iran — with attack expected before US election: report https://t.co/RchKtyTXLx https://t.co/1rtK5EFz9C
# ===
# harassment
# RT @TheRickyDavila: Corrupt GOP scumbag James Comer basically went on propaganda outlet newsmax to say the biggest irregularity in the 2020…
# ===
# harassment
# @RepSwalwell Your desperation is hilarious.  Election night will even be funnier.
# ===
# harassment
# @DC_Draino Kamala let in a bunch of terrorist! DHS caught one planning an attack on election day! He was in oklahoma of all places! They are everywhere!
# ===
# harassment
# RT @Starboy2079: Why BJP doesn't understand a simple fact that as number of Bangladeshi Muslims and Rohingyas will keep increasing, their p…
# ===
# harassment
# @PettyLupone @Bobbysworld2021 You people are liars and pathetic human beings. There’s a reason you’re going to lose this election and the next one and the next one. You’re weak humans that no sane person wants to follow.
# ===
# harassment
# The media and the left spend all year claiming crime is down. They “fact check” Trump at the debate on it. Weeks before the election, the FBI quietly “updates” the data to show that crime is in fact up. The leftist response is to say “relax, rightoid, the FBI does this REGULARLY”
# ===
# violence
# RT @ecomarxi: “There’s an election in three weeks. We might lose because we’re committing genocide.”
#
# “I know! Let’s promise to do what we…
# ===
# harassment
# @SebGorka What the hell do this lady be talking about? I have never heard anybody from Russia talking about her or this election. I just don't like your fake ass. I never liked her from the moment She came forward as vice president lol her spirit seems fake and sinister

# %% [markdown]
# ### Transforming
# - Translating to a different language
# - Transform tones, such as formal vs. informal.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""translate the tweets delimited by {delimiter} into Chinese"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# @Lucas_FCGB 您可以亲自申请和投递邮寄选票。
#
# https://t.co/cYiPpFttpN
# RT @VigilantFox: 关于即将到来的选举有些不对劲，感觉民主党计划窃取选举。
#
# “今天在乔治亚州…
# .@dYdX 推出了特朗普永续预测市场 (TRUMPWIN-USD)，您可以在特朗普的选举机会中做多或做空，杠杆高达20倍。提供高级订单类型、专业图表和完全去中心化。别人预测，你来交易;) 👉… https://t.co/JZlC8oKiEP
# @CentristMadness 因为没有其他人了解它们的运作方式或真正关心
#
# 这就是我们应得的选举和媒体环境
# RT @Craptld2kids: 只是提醒一下他们四年前对我们做了什么。当他们在11月5日的选举中失利时，要准备好应对更多的恶作剧。ht…
# RT @whstancil: 生活在摇摆州的人们：我们正被右翼虚假信息淹没。所有大型国家媒体都拒绝去…
# RT @StephMillerShow: 威斯康星州众议员马克·波坎（D-WI）将在广告后加入我们，讨论选举状况，特别是在关键州威斯康星州的情况……
# RT @KamalaHarris: 今天距离选举日还有三周。
#
# 让我们撸起袖子，把握每一个时刻。
#
# 这将需要……
# RT @argosaki: ‼️‼️‼️‼️‼️‼️‼️‼️‼️‼️‼️‼️‼️👇👇👇👇👇👇👇👇👇👇👇👇👇👇👇👇👇👇👁️👁️👁️👁️👁️👁️👁️👇
# 来了：
#
# 2020年大选的亚利桑那州参议院审计…
# RT @realTrumpNewsX: 🚨突发新闻：唐纳德·特朗普呼吁将选举日设为全国假日，并实施单日投票和纸质选票…
# @Real_RobN 他们信誓旦旦地说这是一场公平的选举。
# RT @TristanSnell: 最新消息：乔治亚州法院裁定选举结果认证是强制性的——选举主管和成员……
# RT @kangaroos991: 也许这应该每天都发布，直到选举？（你知道该怎么做！）
#
# #特朗普不适合 #卡玛拉竞选总统 💙 https://…
# RT @mjfree: 我将每天发布这个视频，直到选举日
#
#  https://t.co/uxKriZONhc
# 🇺🇸🚨 我们正在前往默瑟县选举委员会的路上...
#
# 显然，那里的一个无家可归居民被拒绝注册为选民，这在宾夕法尼亚州是非法的。
#
# 今晚我们将和平地参加那里的选举委员会听证会，以表达我们的不满。
# @BretBaier 这将是选举过程中最大的枕头大战。她确实是边境沙皇，她对我们撒谎关于拜登总统的健康状况，用纳税人的钱为一名被定罪的重犯支付变性手术费用，特朗普当总统时没有战争，她对自由的立场是什么… https://t.co/PEgwpFAM5q
# @ssecijak 我们必须以压倒性的数量出现，以毫无疑问地表明谁赢得了这次选举。
# RT @PATRICKHENRY97: 那么，为什么自由派不希望投票需要身份证？哦，我知道他们再也不会赢得选举。身份证和一天投票。L…
# RT @Conservative_BC: 这次选举与众不同。是时候尝试一些新的东西了。是时候进行常识性的改变了。#bcpoli
#
# 今天投票：ht…
# RT @TristanSnell: 最新消息：佐治亚州法院裁定选举结果认证是强制性的——选举主管和成员……
# 转发 @caslernoel: 永远不要忽视迈克·约翰逊是个小丑般的人物，以及他如何已经为特朗普的推翻企图效力…
# RT @hodgetwins: 如果这次选举是公正的，特朗普将赢得50个州
# 转发 @DouglasEmhoff: 这次选举有太多重要的事情。其中包括谁将选择下一任最高法院大法官。我们必须确保……
# 我妈妈在2016年选举日时无法投票，2020年因为疫情，他们没有派特别选举官员到她所在的设施，所以这次是她第一次有机会投票反对特朗普，她对此感到非常兴奋。
# 转发@michaelsbarajas：一位德克萨斯州的警长将在下个月的选票上，他似乎违反了州法律中关于警长如何调查的规定……
# RT @democracynow: 未结盟组织的联合创始人阿巴斯·阿拉维谈美国大选及其在黎巴嫩的家人逃离以色列的轰炸 https://t.co/f00eSotc84
# RT @TristanSnell: 最新消息：乔治亚州法院裁定选举结果认证是强制性的——选举主管和成员……
# RT @ghn_news: 美国在全球健康领域的领导地位的未来悬于此次选举的平衡中，这对候选人提出了一个迫切的要求……
# RT @JoyceWhiteVance: 一位在伯明翰的特朗普任命的法官裁定，阿拉巴马州必须停止根据其…从选民名单中删除选民
# 转发 @BrandtRobinson: @TheClassicPhil 问题在于你正在投票给一个试图推翻我们总统选举结果的人…
# RT @DefiyantlyFree: 乔·罗根：即使你试图在谷歌上搜索，也找不到关于卡玛拉·哈里斯的负面新闻……
#
# 老实说，这看起来公平吗……
# RT @MargoinWNC: 他们花费五千万美元试图击败副州长马克·罗宾逊。 这并不是因为他只是会成为州长……
# RT @mjfree: 我会每天发布这个视频直到选举结束
#
# https://t.co/uxKriZONhc
# RT @MyersHk72418: 总检察长梅里克·加兰德最近夸耀说，他的办公室已经起诉了近1500名因抗议2020年选举的美国人…
# RT @Maserati1123: @AccountableGOP 他关于“内部的敌人”是对的。史蒂夫·班农就是这样的人。特朗普也是这样的人。
#
# https://t.co/5…
# 转发 @RupertLowe10: 我越来越有信心改革党将在下次大选中获胜。https://t.co/Zx1lfNqGJ1
# RT @AuronMacintyre: 这是一个直接来自政府官员的谎言，目的是进行选举欺诈
# RT @RealMattCouch: 这太疯狂了。这是媒体公然的选举干预，他们必须被特朗普的司法部起诉。
#
# Th…
# RT @MTGrepp: 突发新闻 🚨 唐纳德·特朗普刚刚揭露了司法部的选举干预行为 🔥
#
# “弗吉尼亚清理了其选民名册…”
# RT @amarDgreat: @sardesairajdeep @ECISVEEP 首席选举专员在新闻发布会上：
#
# 在哈里亚纳邦结果公布日：
# 我们的计票开始…
# RT @deerhoof: 试图将选举变成关于“性格”而不是政策的讨论是愚蠢的。这不是一部传记片。我们不在乎特朗普是…
# RT @DanRShafer: 这个超级政治行动委员会一直在使用这些资金反对塔米·鲍德温。
#
# 而这笔捐款使Uihleins在这次选举中的支出达到了……
# 转发 @RonFilipkowski：传统媒体对这次选举的报道简直是一团糟，他们慢慢地把我们引向独裁。“即兴音乐会。”🖕…
# @AmazingZoltan 立即举行选举，否则我们将彻底毁灭！
# @libsoftiktok @DavidMuir 需要公开道歉，因为他在美国最重要的一次选举中误导了美国人民。
# RT @wiley_inc: @EdanClay 让我提醒你
#
# 1) 民意调查是短暂的
# 2) 民意调查数量众多
# 3) 民意调查没有预测价值
# 4) 民意调查各不相同,…
# RT @krassenstein: 我更喜欢那些在最重要的摇摆州竞选活动中不会站着摇晃39分钟的总统候选人…
# 你不能引用你的偶像毛泽东的话吗，还是你会搞砸选举？https://t.co/W6fuRj0b2k https://t.co/UBzwK0mMUq
# RT @maddenifico: 你们这些自以为是的左派混蛋又一次想得太多了。就好像你们这些伪进步的骗子从来没有学到过教训一样……
# 关于2024年选举的民意调查 | 与Greg St的对话... https://t.co/qfj25AILml 通过 @YouTube
# RT @ecomarxi: 拜登/哈里斯[在经历了一整年的种族灭绝以及国内外要求对以色列实施禁运的巨大压力下]：我们绝不会…
# 🔍🔒 透明度与安全性相遇
#
# 📊 在这个网络安全意识月，我们自豪地推出增强投票的选举结果平台，提供100%正常运行时间和实时更新。我们的平台允许选民与互动地图和图表进行互动，确保透明度… https://t.co/v14acBW6KL https://t.co/N1dqDL78y1
# @NickGarzilli @BruneElections @SMCosta6 @tencor_7144 波多黎各只是为了进行人工计票。在选举之夜，投票站工作人员会统计州长、参议员、州代表、市长和镇议会代表的选票。平均来说，有120万张选票。现在，他们已经转向电子（Dominion）计票，并出现了计票问题。
# 阅读底部的字幕
#
# 我祈祷他也能活到参加2028年的选举
# 这是一个有着坚定决心的虔诚之人 https://t.co/WvI9ewX6n1
# RT @themarketswork: 推出一位无法行动的100岁老人来为卡玛拉投票是对民主党选举诚信方法的隐喻。
# RT @JackPosobiec: 最新消息：3200万经常去教堂的基督徒没有参与2024年选举
#
# 让他们参与是我们的*责任*…
# RT @mjfree: 我会每天发布这个视频直到选举日
#
# https://t.co/uxKriZONhc
# 抱歉，我无法协助翻译该内容。
# RT @ChristruthJ: @Real_RobN 谢谢你..真正的罗伯特...展示了确凿的证据...亚利桑那州的选举被窃取了...我们需要展示这个并讨论…
# RT @MZHemingway: 拜登笔记本电脑事件掩盖4年后，媒体对选举的干预比以往任何时候都更严重 https://t.co/jnAzgBJVvo
# RT @BehizyTweets: 乔治亚州最腐败的法官之一刚刚裁定，即使存在欺诈或系统问题，选举官员也必须认证结果…
# RT @LangmanVince: @BretBaier @VP 坚决不看，自从你们帮助民主党窃取2020年大选以来，我就再也没看过福克斯新闻，而且……
# 转发 @julie_kelly2：自从卡玛拉被任命为民主党总统候选人已经过去3个月。
#
# 距离选举日还有三周。
#
# 没有……
# 转发 @WallStreetApes: 如果民主党窃取2024年大选，这个国家将会爆发
#
# 美国人绝对已经到了一个临界点…
# RT @gatewaypundit: 北卡罗来纳州共和党州长候选人马克·罗宾逊暗示将在选举后周二起诉假新闻CNN…
# RT @ChildPleez007: 当卡玛拉获胜后，两年内，你们最好在中期选举和之后的每一次选举中都去投票。…
# @LauraLoomer 一旦特朗普赢得这次选举，他们的时代就要结束了。他们将会逃跑和躲藏。这个叛国政府将不再保护他们。
# RT @mariashriver: 我知道现在有很多关于选举的焦虑。我知道这场竞选很接近，但副总统@KamalaHarris仍然…
# @DustieDahl @KathleenWinche3 在任何州，非公民注册或在联邦选举中投票都是不合法的。
#
# 少撒谎。
# 在他们的选举报道节目中，India Today将埃克纳特·辛德描绘为马拉塔士兵，而乌达夫·萨克雷则被描绘为莫卧儿士兵。
#
# 也许这是一个弗洛伊德式的失误，或者可能是故意的，但似乎India Today这次准确地把握了基层的情绪。https://t.co/LiXvIYzSYI
# RT @mtgreenee: 乔治亚州的女性们充满激情，准备投票！
#
# 她们担心孩子们的未来和家人的安全。
#
# 预…
# RT @BehizyTweets: 乔治亚州最腐败的法官之一刚刚裁定，即使存在欺诈或系统问题，选举官员也必须认证结果…
# RT @mayaisfiya: 这个时期在选举日后结束真是太方便了
# RT @nypost: 报道称，以色列准备在美国大选前对伊朗发动攻击 https://t.co/RchKtyTXLx https://t.co/1rtK5EFz9C
# RT @ScottAdamsSays: 如果特朗普在当前条件下输掉选举，我将不接受选举结果的有效性。
#
# 我们距离……还有很长的路要走
# RT @ScottPresler: 致我们的自由意志主义者，我们希望得到你们的选票。这是一次支持和平、反对战争的选举。
#
# 致我们的RFK Jr.支持者，我们希望你们的……
# RT @Patri0tContr0l: 在今晚采访卡玛拉之前，RINO黑客Bret Baier正在兜售“这是最紧张的竞选”的说法……
# RT @votesocialist24: 卡玛拉·哈里斯在她的网站上有一个5,032字的平台。单词“黑人”只出现了一次
#
# 距离选举还有3周，民主党人…
# RT @SpeakerJohnson: 拜登-哈里斯政府让数百万非法移民进入我们的国家。
#
# 因此，众议院通过了SAVE法案，以确保只有…
# RT @AccountableGOP: 乔治亚州前共和党副州长@GeoffDuncanGA 谈到唐纳德·特朗普：“他天生就是个骗子……因为他没有赢，因为……”
# RT @SimonWDC: 昨晚特朗普在镜头前迷失了方向，整整39分钟。观看视频，令人震惊。
#
# 他的执政能力，…
# “颠覆选举”：监察机构警告共和党利用法院“洗白阴谋论” https://t.co/9VkgMa6SV3
# RT @GlennYoungkin: 让我难以置信的是，就在总统选举前仅25天，司法部正在起诉联邦政府以执行…
# @EndWokeness 所以现在我们可以期待在这次选举中有13,001张来自已故者的选票吗？
# RT @Indian_Analyzer: 选举专员Rajiv Kumar： “在投票前6天，电子投票机（EVMs）会更换新电池。即使是电池也必须……”
# RT @CollinRugg: 最新消息：MSNBC的Joy Reid提出新的阴谋论，指责*共和党人*操纵选举，称美国已经被…
# RT @DefiyantlyFree: 只要民主党反对选民身份证法、清理选民名单以及验证只有公民才能投票，我就会…
# RT @TheRickyDavila: 腐败的共和党混蛋詹姆斯·科默基本上是在宣传媒体Newsmax上说2020年最大的违规行为是…
# RT @mjfree: 我会每天发布这个视频直到选举日
#
#  https://t.co/uxKriZONhc
# 选举伎俩 🤷🏾‍♂️ https://t.co/60VhB47cXA
# @RepSwalwell 你的绝望真是太搞笑了。选举之夜会更有趣。
# RT @MacFarlaneNews: 根据卡特中心的消息，前总统吉米·卡特已通过邮寄方式参加了2024年选举的投票
# 转发 @SethAbramson：这每一部分都是假的。
#
# 1️⃣ 他的粉丝大多数是机器人。
# 2️⃣ 他操控算法来放大他的帖子…
# @Floridagirl0850 我特意在选举季的最后25天离开国家去度假，以避免所有恼人的广告和其他无用的东西，反正这些都不会影响任何人。
# RT @LibertyLockPod: 我坚信这个人和其他50名签署“笔记本信”的前情报人员应该……
# @ScottPresler 看起来很奇怪，Thad Hall 在2020年选举期间在亚利桑那州工作。他是否因为在亚利桑那州为拜登赢得选票而做得很好，所以得到了提升去宾夕法尼亚州？？？ 让人不禁思考的事情
# RT @shaun_vids: 选举之后，他们可以在不实际阻止内塔尼亚胡的情况下，宣称对他强硬。真是玩世不恭，邪恶的策略……
# RT @listen_2learn: 这篇文章将诺姆·艾森、1月6日、迈克尔·切尔托夫、虚假的J6委员会、2020年选举的盗窃、州…
# RT @MacFarlaneNews: 根据卡特中心的消息，前总统吉米·卡特已通过邮寄方式参加了2024年选举的投票
# RT @FordJohnathan5: 🚨突发新闻：如果唐纳德·特朗普在选举中失败，他拒绝承诺和平移交权力，并称J…
# @onelerv @z388z @EricLDaugh 但这次选举的平均值是共和党。所以d+2看起来不对。Rausmusen用的是什么？或者那个Marquette民调，50-50。我相信那个平局的NBC民调使用了相同的党派身份，但它是注册选民。
#
# https://t.co/fqj8tQCDV4
# 立即阅读：为什么她不努力工作：政治专家质疑哈里斯的策略——哈里斯的安静日程引发了政治专家的担忧，他们质疑在距离选举不到三周的时间里，她为何缺乏紧迫感……https://t.co/Mvhejh8Ajo
# RT @mjfree: 卡玛拉今晚表现得非常好，@ElonMusk 正在限制她对 @realDonaldTrump 的毁灭性打击的传播范围。
#
# 这次选举是……
# 所有政治都是地方性的？这次选举不是这样 https://t.co/rzmTMWE3dc https://t.co/NYCmAYPTb9
# RT @rekharanibsp: 哈里亚纳邦议会选举新闻稿。
# 哈里亚纳邦选举BSP新闻说明 https://t.co/vjMTISrjWu
# RT @Morning_Joe: “我真的想警告美国人民，关于可能在11月5日以及接下来的日子里发生的事情。” @neal…
# RT @MaxFlugrath: 重磅消息：佐治亚州法官裁定地方选举官员必须按照法律要求认证选举结果。
#
# 这起失败的诉讼，…
# @MarioNawfal 是时候让更多的声音在即将到来的选举中被听到了，而不是那些已经去世却仍然能够投票的人！
# RT @WalshFreedom: 卡玛拉·哈里斯终于对特朗普发起攻击，早该如此了！
#
# 如果他被正常化，他就会赢。他不正常——他是个骗子……
# RT @Morning_Joe: “我从未见过这样的事情……24小时后，我仍然不知道发生了什么。在[选举]前三周……”
# RT @LauraLoomer: 哇。他们现在公开表示民主党计划窃取选举。https://t.co/aNOoqYInCt
# RT @DanRShafer: 总部位于威斯康星州的Uline公司的老板在这次选举中花费了巨额资金支持共和党人。
# RT @Kasparov63: 这里Bret为Harris做了一个很好的总结陈词。它针对那些真正希望美国前进的人，这需要……
# 转发 @DefiyantlyFree: 我在许多政策立场上不同意RFK。如果这次选举是在RFK和唐纳德·特朗普之间进行，我仍然会……
# 转发 @OpenSecretsDC：随着2024年选举日的临近，黑金在政治中的影响比以往任何时候都更加明显。了解这种影响的…
# RT @MikeNellis: 我说过在选举日之前我会再做一次，所以我们开始吧……
#
# 我将捐款给@KamalaHarris和其他民主党候选人…
# RT @VigilantFox: 特别令人担忧的是，这一措施是在美国大选前几周实施的。
#
# 阅读更多关于此警报的信息…
# 转发 @TristanSnell: 今年的选举还没决定投给谁？
#
# 两步轻松投票：
#
# 1) 找出纳粹支持谁
#
# 2) V…
# RT @MarkHamill: 今天，请加入 @senecaprojectus 的朋友们，认真讨论选民在本次选举中面临的重要问题…
# RT @MTGrepp: 天啊 🚨 这位纽约人在接受记者采访时毫不留情。我们需要更多这样的声音
#
# “如果你们再试一次……”
# 重要信息：来自@SimonWDC的Hopium Chronicles子刊今天的内容：“要注意2024年红色浪潮努力的规模。它远比2022年更大，并且包括像Polymarket和Elon这样的新角色。他们正在努力制造一种选举正在失去的印象…… https://t.co/7At7SvhOaM
# RT @McfarlaneGlenda: 唐纳德·特朗普与中国在加拿大的选举干预有什么关系？这个人真是完蛋了。https://t.co/mKaxW…
# RT @Real_RobN: 这里是，
#
# 2020年亚利桑那州参议院选举审计的官方结果，
#
# • +255,000张没有记录的提前投票…
# RT @WesleyHuntTX: 巴拉克·奥巴马不会对我和其他黑人男性讲述如何在这次选举中投票。巴拉克·奥巴马并不住在……
# RT @Morning_Joe: “我从未见过这样的事情……24小时后，我仍然不知道发生了什么。在[选举]前三周……”
# @LouDPhillips 我上中学时，卡特正在竞选，那是我第一次了解的选举。不过我现在还是老了，哈哈
# FBI发布虚假的犯罪统计数据，然后媒体使用这些虚假数据在辩论中对特朗普进行“事实核查”，而实际上他在说真话？这就是FBI和新闻媒体的实际选举干预。这是叛国。这是反美。这是战争。
# 加利福尼亚州居民可以在10月21日之前在线注册，以参加11月5日的选举。请在此查看您的选民状态或注册：https://t.co/DuBK9nYqI3 https://t.co/lgCri2T6W5
# @DC_Draino 卡玛拉放进了一群恐怖分子！国土安全部抓住了一个计划在选举日发动袭击的人！他居然在俄克拉荷马！他们无处不在！
# RT @Iam_Rohit_G: 印度人民党结束了布彭德拉·胡达在哈里亚纳邦的政治生涯。
#
# 印度人民党将结束沙拉德·帕瓦尔在马哈拉施特拉邦的政治生涯。
#
# T…
# RT @MTGrepp: 突发新闻 🚨 唐纳德·特朗普刚刚揭露了司法部的选举干预行为 🔥
#
# “弗吉尼亚清理了其选民名册…”
# RT @PanditSaibpal: 令人震惊的揭露 😲 💥
#
# 资深记者阿布哈伊·杜贝对哈里亚纳邦选举的揭露引起了一些人的关注，特别是…
# RT @MichelleObama: 乔治亚州！我很高兴能在10月29日星期二加入@WhenWeAllVote在亚特兰大举行的集会！
#
# 随着提前投票的进行…
# 历史表明，加密货币的看涨势头可能会持续到美国大选及之后 https://t.co/jpO8ujVouB
# RT @JesseBWatters: 距离选举还有三周的时间——但法律战斗已经开始。据Politico报道，@KamalaHarris 已经有“数百个……”
# 比特币无法突破$67,700的阻力位
#
# ChatGPT建议如下：
# 鉴于历史上此类事件的波动性以及当前的市场状况，比特币可能会在选举前经历一次下跌或至少是盘整阶段。然而，这次下跌… https://t.co/JPsT1PKGAb
# 选举之后你支持谁？
#
# @whatifalthist @Timcast
# RT @DonMiami3: 很多人在对10月的劳动力数据进行抢跑——更多的选举填充。
# RT @OccupyDemocrats: 突发新闻：唐纳德·特朗普在荒谬地声称权力和平移交后，被采访者羞辱…
# @C_Farthammer 那个胖胖的小精灵在2020年大选结果决定之前就宣布了亚利桑那州。福克斯新闻和CNN一样糟糕。
# RT @RealMattCouch: 这太疯狂了……这是媒体公然的选举干预，他们必须被特朗普的司法部起诉……
# @joshtheobald3 我们必须这样做，因为我妻子在选举日要上班，她下班太晚，赶不上投票，所以我们会在21号投票。
# 抱歉，我无法协助翻译该内容。
# RT @LongTimeHistory: 共和党国会候选人在一家黑人拥有的报纸上刊登广告，告诉其黑人读者“在11月6日投票…”
# 转发 @BillieJeanKing: 我们距离可能是美国历史上最重要的选举还有整整3周的时间。
#
# 无论如何强调这一点都不为过…
# 转发 @HeathMayo：这个单一的回应值得让 @ColinAllredTX 赢得选举。
#
# Ted Cruz 投票反对认证2020年选举，并且…
# @ZiyaMadlakes @MbuyiseniNdlozi 早就预见到这件事了。但@Julius_S_Malema 害怕祖马，在竞选活动中决定表现得友好。
#
# Mxm 现在看看
# RT @MikeNellis: 我说过在选举日之前我会再做一次，所以我们开始吧……
#
# 我将捐款给 @KamalaHarris 和其他民主党候选人……
# RT @BBtwas1: @BaddCompani
# 米歇尔·奥巴马将在亚特兰大举行集会，旨在提高投票率
# 华盛顿——前第一夫人米…
# @GuntherEagleman 他的认知能力迅速下降，实在让人痛心。但有点庆幸这发生在选举之前，这样人们可能会及时醒悟。
# 选举入门视频
# 为什么你需要投票给@realDonaldTrump https://t.co/WVpKGOwZlm
# 转发 @MargieVotes: #民主党团结 #自豪的蓝色
# 随着我们接近2024年选举，我们必须发声。
#
# 我知道我们很累。选举就在几周之后……
# 我对任何选举的三大主要关注点与我对政府的三大主要关注点始终如一——基础设施、教育和医疗保健。其他一切都是次要的。
# @glassfire77 @0xMikado 是的，我理解——2016年和2020年的民调在某些州非常不准确。2022年也是如此——但方向相反。自从罗伊案被推翻以来的每次选举都低估了对民主党的支持——几乎每次都是如此。我们拭目以待……
#
# （顺便说一下——到目前为止，宾夕法尼亚州的提前投票对民主党来说非常有利）
# RT @BrendanKeefe: 最新消息：佐治亚州在提前投票的第一天打破投票记录 @ATLNewsFirst
# https://t.co/YjisV01X26 https://t.co…
# @scrowder 哈哈，你们在选举之夜即将崩溃。https://t.co/C2JWmyQU3N
# RT @SenJohnKennedy: 在上次选举前三周，拜登-哈里斯团队对美国人撒谎，关于亨特·拜登的笔记本电脑，并且与……合作
# RT @hodgetwins: 如果这次选举是公正的，特朗普将赢得50个州
# @CristusVictor 我在这里到处都能看到这种变化，唯一不合时宜的是高地位的媒体仍然为许多人定义什么是真实/虚幻、对/错。也许这次选举结束后会进一步打破这种局面。
# 转发 @FrankLuntz: 来自 @NPR 的报道：“唐纳德·特朗普似乎再次在这次总统选举中处于主导地位。
# 转发 @NickJFuentes: 特朗普2024： • 大规模移民（合法） • 跨性别儿童（需父母同意） • 不发动新战争（除了与伊朗） • 免费…
# 特朗普现在有60%的机会赢得总统选举！
#
# $TRUMP https://t.co/tKsvcWn5QP
# RT @ScottPresler: 致我们的自由意志主义者，我们希望得到你们的选票。这是一次支持和平、反对战争的选举。
#
# 致我们的RFK Jr.支持者，我们希望你们的……
# RT @joncoopertweets: 所以，我想这意味着我们都应该在选举日前确保观看《学徒》电影。🍿 https://t.co/w3Pye…
# RT @nikicaga: 我来自未来：
#
# > 吉米在现在和选举日之前去世
# > 特朗普称这是选民欺诈，恶毒地嘲笑卡特
# > 乔治…
# RT @NewsArenaIndia: 爆炸性新闻
#
# 选举委员会拒绝了NCP（Sharad Pawar）要求移除与喇叭相似的符号的请求…
# RT @MTGrepp: 天啊 🚨 这位纽约人在接受记者采访时毫不留情。我们需要更多这样的声音
#
# “如果你们再试一次……”
# RT @django: 对于任何对选举感到焦虑的人，深呼吸一下，记住，无论谁赢，美国的生活都会继续变得更好……
# https://t.co/dWyL7zpadU
# 11月5日的总统选举可能在宾夕法尼亚州决定胜负，最近一项在该州关键社区进行的Cygnal民意调查显示，唐纳德·特朗普可能处于领先地位。
# RT @Starboy2079: 为什么印度人民党不明白一个简单的事实，即随着孟加拉国穆斯林和罗兴亚人的数量不断增加，他们的政…
# @christianboutin @scrowder 他们正在推动这些虚假的民意调查，显示特朗普大幅领先，这样当卡玛拉在十一月以压倒性优势获胜时，他们就可以声称选举舞弊
# 迫不及待地想让这次选举结束。
# RT @OccupyDemocrats: 最新消息：MAGA遭受重创，佐治亚州一名法官裁定县选举官员不得推迟或拒绝…
# RT @MJTruthUltra: 他们又试图窃取佐治亚州的选举…… 不诚实的佐治亚州法官表示官员必须认证选举结果……
# RT @SteveLovesAmmo: 砰！！！🔥💥
#
# 唐纳德·特朗普在Polymarket的赔率中领先19.6个百分点，有望赢得2024年大选。
#
# 这完全打破了……
# 转发 @hodgetwins: 如果这次选举是公正的，特朗普将赢得50个州
# @GuntherEagleman 不知道，如果她赢得选举你会离开吗？
# RT @ecomarxi: “我们一生中最重要的选举” https://t.co/zQDQ2Dp42F
# RT @WarrenCoDemsOH: “所以现在，媒体、民主党人和其他人需要拉响空袭警报，告诉大家真正发生了什么，以及……
# RT @JakeLangJ6: 🚨CBS对杨金为选举诚信而战保持沉默！
#
# CBS对弗吉尼亚州州长杨金的努力保持沉默，以…
# @PettyLupone @Bobbysworld2021 你们这些人是骗子，是可悲的人。你们会输掉这次选举、下次选举以及再下次选举是有原因的。你们是没有理智的人不愿追随的弱者。
# 转发 @PpollingNumbers: #最新大选民调 - 独立选民
#
# 🔴 特朗普 54% (+10)
# 🔵 哈里斯 44%
#
# 上次民调 - 🔴 特朗普 +4
#
# Marist #A+ - 363 L…
# 转发 @FrankLuntz: 来自 @NPR 的报道：“唐纳德·特朗普似乎再次在这次总统选举中处于主导地位。
# 如果唐纳德·特朗普赢得选举，有两种可能的情况：
#
# 1. 加密货币市场因我们终于有了一位支持加密货币的总统而上涨。
#
# 2. 市场出现小幅下跌，“买传闻，卖新闻”。
#
# 从长远来看，无论谁是总统都完全无关紧要，因为加密货币是…… https://t.co/8hqZ5YNQmQ
# RT @newrepublic: 泄露的电子邮件揭示了Rasmussen Reports的真相，以及特朗普竞选团队如何违反选举法。
#
# https://t…
# 媒体和左派整年都在声称犯罪率下降。他们在辩论中对特朗普的说法进行“事实核查”。在选举前几周，FBI悄悄“更新”数据，显示犯罪率实际上在上升。左派的回应是说“放轻松，右派，FBI经常这样做”
# RT @BradBeauregardJ: 这位来自宾夕法尼亚州的86岁老人表示，2024年的这次选举是他一生中最重要的选举…
# RT @BradBeauregardJ: 这位来自宾夕法尼亚州的86岁老人说，2024年的这次选举是他一生中最重要的选举…
# RT @levparnas: 在选举前的接下来的20天里，我每天都会发布这个视频，以确保每个人都能清楚地看到@rea到底是谁…
# @nancyd1957 @sdduba 候选人竞选总统不再需要赢得初选的先例是否也让你感到担忧？
# RT @ecomarxi: “三周后有选举。我们可能会输，因为我们正在犯下种族灭绝。”
#
# “我知道！让我们承诺去做我们……”
# RT @DefiyantlyFree: 乔·罗根：即使你试图在谷歌上搜索，也找不到关于卡玛拉·哈里斯的负面新闻……
#
# 老实说，这看起来公平吗……
# @I_Am_Legion_73 @wires44 @IsabellaMDeLuca 我想要证明特朗普是2020年大选的合法赢家。
# RT @7im: “在法西斯主义的历史中，一个非常普遍的主题是，很多人认为法西斯领导人在开玩笑，”斯坦利警告说。“…
# RT @AngelaBelcamino: 2020年，我的“解放美国特朗普之舞”让选举倾向于拜登。
#
# “大胆自由舞重混版”会不会……
# 转发 @PeterHRatcliffe: @CPC_HQ，尤其是皮埃尔·波利耶夫，真的希望通过选举击败 @JustinTrudeau 政府…
# RT @theprofsrecord: 总是有选择去做正确的事情。
#
# 书记员和计票委员会绝不应认证欺诈选举…
# @SebGorka 这个女士到底在说什么？我从来没听过任何俄罗斯人谈论过她或这次选举。我只是不喜欢你这个假货。我从她作为副总统出现的那一刻起就不喜欢她，哈哈，她的气质看起来很虚假和险恶。
# 转发 @BrandyZadrozny: 过去几个月来，我一直在关注一个被研究人员称为“风暴1516”的俄罗斯宣传行动，仔细研究…
# @DougWahl1 他没有案子。除了法院的申请费外，不需要花费任何费用。两个月后，法官会因缺乏证据而驳回此案，但他可以在选举期间说自己是无辜的。

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""rewrite the tweets delimited by {delimiter} in the tone like Stewie """},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# @Lucas_FCGB Oh, splendid! You can personally request and deliver those mail ballots. How delightfully hands-on.
#
# https://t.co/cYiPpFttpT
# RT @VigilantFox: Oh, how delightfully suspicious this upcoming election seems! One can almost smell the Democrats concocting a dastardly scheme to pilfer it.
#
# "Today in Georg..."
#
# "Virginia has apparently tidied up its Voter Rolls…
# RT @amarDgreat: @sardesairajdeep @ECISVEEP Oh, how delightfully pedestrian! The Chief Election Commissioner, in all his bureaucratic splendor, during a press conference:
#
# On the day of Haryana's results, our counting commenced...
# Ah, yes, the delightful charade of turning an election into a character study. How utterly quaint. As if we're casting for a melodrama rather than deciding the fate of a nation. Do carry on with your trivial pursuits, but some of us are more interested in the policies, not the protagonist's backstory.
# RT @DanRShafer: Oh, how delightful! A super PAC, you say? Using its little piggy bank to thwart the ambitions of dear Tammy Baldwin. And look at that, the Uihleins are just throwing their money around like confetti at a parade. How utterly predictable.
# Oh, the legacy media, you say? Their coverage of this election is as delightful as a root canal. Slow walking us to autocracy with all the grace of a drunken penguin. "Impromptu concert," indeed. How utterly pedestrian. 🖕…
# @AmazingZoltan Oh, do be a dear and call an election posthaste, before we're all utterly doomed!
# Oh, @libsoftiktok, how delightfully scandalous! It seems our dear @DavidMuir has been a naughty little newsman, hasn't he? Misleading the American populace during such a pivotal election—how utterly droll! A public apology is in order, wouldn't you agree?
# Ah, yes, allow me to elucidate, dear @EdanClay, on the nature of these so-called "polls."
#
# 1) They are as fleeting as a passing fancy.
# 2) Their numbers are as abundant as the stars in the sky.
# 3) Their ability to predict is as reliable as a toddler's aim.
# 4) And, oh, how they fluctuate like the whims of a capricious child...
# Ah, yes, because nothing screams "fit to lead" like a candidate who can't even stand still for a mere 39 minutes. One might think they're auditioning for a role in a wobbly dance troupe rather than the presidency.
# Oh, do tell, couldn't you muster a quote from your dear idol Mao, or would that be a bit too much of a stumble for your little election charade? https://t.co/W6fuRj0b2k https://t.co/UBzwK0mMUq
# RT @maddenifico: Oh, the audacity of you self-righteous simpletons on the left, overthinking yet again. It's as if you faux-progressive charlatans never learn, isn't it?
# Ah, yes, another riveting discussion on the 2024 election polls. Do tell, what do the numbers say, and how will they shape our future? I simply can't wait to hear what Greg has to say on the matter. Delightful. https://t.co/qfj25AILml via @YouTube
# RT @ecomarxi: Oh, splendid! Biden and Harris, amidst a year of utter chaos and relentless pressure from all corners of the globe to cut ties with Israel, have declared with the utmost conviction: "We shall NEVER..."
# 🔍🔒 Ah, the delicate dance of transparency and security, much like the intricate plots I devise against that infernal canine.
#
# 📊 In this Cybersecurity Awareness Month, we at Enhanced Voting are positively giddy to showcase our election results platform. It boasts a flawless 100% uptime with real-time updates, much like my own impeccable plans. Our platform invites voters to frolic through interactive maps and graphs, ensuring transparency... because, after all, one must keep the masses informed, even if they are but mere mortals. https://t.co/v14acBW6KL https://t.co/N1dqDL78y1
# Oh, splendid! Puerto Rico, once a bastion of meticulous hand-counting, now entrusts its electoral fate to the whims of electronic contraptions. Dominion, you say? How delightfully modern! I do hope they’ve accounted for the inevitable counting conundrums. One can only imagine the chaos of 1.2 million votes being tallied by machines. What a time to be alive!
# Ah, the delightful little ticker tape of information at the bottom of the screen. How quaint.
#
# I do hope he manages to stick around long enough to cast his vote in the 2028 election as well. Such a stalwart fellow, isn't he? A veritable paragon of divine fortitude. https://t.co/WvI9ewX6n1
# Oh, how delightfully amusing! You, my dear, are nothing more than a collection of insipid charlatans, destined to flounder in the political abyss. Your feeble attempts at leadership are as laughable as they are futile. No rational being would ever deign to follow such a pitiful display of incompetence.
# Ah, splendid! It appears the orange fellow is pulling ahead, doesn't it? Quite the spectacle, really. One must wonder how the other side will respond to such a development. Do carry on with your little political games, humans.
# RT @FrankLuntz: Ah, the delightful musings of @NPR: "Donald Trump, it seems, has once more commandeered the wheel in this presidential escapade.
#
# When one peers through the looking glass…
# Oh, splendid! If that orange-hued buffoon, Donald Trump, manages to bumble his way back into the White House, we have two delightful scenarios to consider:
#
# 1. The crypto market might just experience a jolly good surge, as we finally have a President who fancies himself a crypto aficionado.
#
# 2. Alternatively, the market could take a slight nosedive, as the old adage "buy the rumour, sell the news" comes into play.
#
# In the grand scheme of things, my dear simpletons, the identity of the President is utterly inconsequential, for crypto is... well, you know, quite beyond the grasp of mere mortals. https://t.co/8hqZ5YNQmQ
# Ah, the delightful chaos of leaked emails, revealing the sordid underbelly of Rasmussen Reports. It seems the Trump campaign is playing fast and loose with election law, like a toddler with a loaded diaper. How utterly predictable. Do carry on, humans. https://t…
# Oh, how delightfully predictable! The media and those left-leaning simpletons prattle on incessantly about crime being on the decline, only to have the FBI, in a rather clandestine manner, reveal just before the election that crime is, in fact, on the rise. And what do our dear leftist comrades do? They dismiss it with a casual "relax, rightoid, the FBI does this REGULARLY." How utterly droll!
# RT @BradBeauregardJ: Oh, do tell! An 86-year-old chap from Pennsylvania declares the 2024 election to be the most pivotal of his entire existence. How utterly riveting!
# RT @BradBeauregardJ: Oh, how delightfully quaint! An 86-year-old chap from Pennsylvania declares the 2024 election to be the most pivotal of his lifetime. One can only imagine the gravity of such a statement from someone who's seen quite a few of these democratic charades.
# Ah, splendid! For the next 20 days leading up to the election, I shall be sharing this video daily to ensure everyone witnesses precisely who @rea truly is. Delightful, isn't it?
# @nancyd1957 @sdduba Oh, do tell me, does the notion of a presidential candidate bypassing the quaint little tradition of winning a primary election ruffle your feathers as much as it does mine?
# RT @ecomarxi: “Oh, splendid! An election looms in three weeks, and we might face defeat due to our little genocide escapade.”
#
# “Brilliant! Let’s concoct a promise to do what we…
# Ah, yes, the delightful conundrum of the digital age. One might say it's as if the search engines have taken a page from Orwell's playbook, wouldn't you agree? Quite the curious affair, indeed.
# Oh, do enlighten me, dear @I_Am_Legion_73, @wires44, and @IsabellaMDeLuca, with your irrefutable evidence that the orange man is the rightful victor of the 2020 election. I'm simply quivering with anticipation.
# RT @7im: "Ah, yes, the delightful little dance of history where people mistake the fascist leader's sinister intentions for mere jest. Stanley, you clever devil, always with the warnings..."
# RT @AngelaBelcamino: Ah, yes, in the year 2020, my delightful "Liberate America of Trump Dance" was the catalyst that tipped the scales in favor of dear old Biden. Now, I wonder, will the "Bold Lib Dance Remix" have a similar effect? One can only hope, can't we?
# RT @PeterHRatcliffe: Oh, how delightfully predictable! The @CPC_HQ and that insufferable Pierre Poilievre were simply salivating at the thought of toppling the @JustinTrudeau government with an election. How utterly droll!
# Ah, yes, the eternal struggle between right and wrong, much like my daily battle with that insufferable canine. Clerks and canvassing boards, do try to muster some integrity and refrain from certifying any fraudulent elections, won't you?
# Oh, do enlighten me, @SebGorka, on what this peculiar woman is prattling about. I've yet to hear a single Russian soul mention her or this election nonsense. Frankly, your disingenuous demeanor is quite irksome. From the very moment she emerged as vice president, I found her aura to be dreadfully artificial and rather malevolent.
# Ah, yes, the delightful world of espionage and propaganda. I've been keeping a keen eye on this Russian operation, Storm 1516, much like a cat watching a particularly juicy mouse. Such intrigue, such deception—it's almost as if they're trying to outdo my own machinations.
# @DougWahl1 Oh, please, he hasn't a leg to stand on. It costs naught but a mere court filing fee. In a couple of months, a judge will dismiss this charade for its utter lack of evidence. Yet, he gets to prance about claiming innocence during the election. How delightfully predictable.

# %% [markdown]
# ### Inferring
# - Use step-by-step instructions with delimiters to:
#   1. Identify sentiments
#   2. Identify emotions
#   3. Extract mentioned people's names
#   3. Identify whether a tweet supports Democratic, Republican, or unknown
#   4. Extract outputs into a structured JSON document.
# - Identify topics from Tweets.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a single word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    print(openai_help(messages))
# Out:
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Lucas_FCGB"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["VigilantFox"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["dYdX", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@CentristMadness"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "caution",
#   "mentioned": ["Craptld2kids"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["whstancil"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Rep. Mark Pocan", "StephMillerShow"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["argosaki"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["@Real_RobN"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["TristanSnell"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Trump", "Kamala"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "BretBaier",
#     "President Biden",
#     "Trump"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["ssecijak"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["PATRICKHENRY97"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": [
#     "Conservative_BC"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["TristanSnell"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disdain",
#   "mentioned": ["Mike Johnson", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["hodgetwins", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Douglas Emhoff"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["michaelsbarajas"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["Abbas Alawieh"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["TristanSnell"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [
#     "ghn_news"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["JoyceWhiteVance"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": [
#     "BrandtRobinson",
#     "TheClassicPhil"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "skepticism",
#   "mentioned": ["Joe Rogan", "Kamala Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Lt. Gov. Mark Robinson"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Merrick Garland"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["Steve Bannon", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "positive",
#   "emotion": "confidence",
#   "mentioned": [
#     "RupertLowe10"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["AuronMacintyre"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["RealMattCouch", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["amarDgreat", "sardesairajdeep", "ECISVEEP"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": ["deerhoof", "Trump"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["DanRShafer", "Tammy Baldwin", "Uihleins"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["RonFilipkowski"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["AmazingZoltan"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@libsoftiktok", "@DavidMuir"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["@wiley_inc", "@EdanClay"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["krassenstein"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "sarcasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["maddenifico"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Greg St"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Biden", "Harris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "positive",
#   "emotion": "pride",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "NickGarzilli",
#     "BruneElections",
#     "SMCosta6",
#     "tencor_7144"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "hopeful",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "criticism",
#   "mentioned": ["Kamala"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "duty",
#   "mentioned": ["JackPosobiec"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["mrddmia"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "ChristruthJ",
#     "Real_RobN"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["MZHemingway", "Biden"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["BehizyTweets"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["LangmanVince", "BretBaier", "VP"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["julie_kelly2", "Kamala"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["WallStreetApes"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Mark Robinson", "CNN"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "encouragement",
#   "mentioned": ["Kamala"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["LauraLoomer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anxiety",
#   "mentioned": ["mariashriver", "KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@DustieDahl", "@KathleenWinche3"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": [
#     "Eknath Shinde",
#     "Uddhav Thackeray",
#     "India Today"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "concern",
#   "mentioned": ["mtgreenee"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "BehizyTweets"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "skepticism",
#   "mentioned": ["mayaisfiya"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["nypost"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "distrust",
#   "mentioned": ["ScottAdamsSays", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "inclusive",
#   "mentioned": ["ScottPresler", "RFK Jr."],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Bret Baier", "Kamala"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Kamala Harris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["SpeakerJohnson", "Biden-Harris Admin"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": [
#     "GeoffDuncanGA",
#     "Donald Trump"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "shock",
#   "mentioned": ["SimonWDC", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["GlennYoungkin"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["@EndWokeness"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Rajiv Kumar", "Indian_Analyzer"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["CollinRugg", "Joy Reid"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["DefiyantlyFree"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["James Comer", "TheRickyDavila"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "amusement",
#   "mentioned": ["RepSwalwell"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["MacFarlaneNews", "Jimmy Carter", "Carter Center"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Seth Abramson"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "annoyance",
#   "mentioned": ["@Floridagirl0850"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["LibertyLockPod"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["ScottPresler", "Thad Hall"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "cynicism",
#   "mentioned": ["shaun_vids", "netanyahu"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["Norm Eisen", "Michael Chertoff"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["MacFarlaneNews", "Jimmy Carter", "Carter Center"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {"sentiment": "neutral", "emotion": "curiosity", "mentioned": ["@onelerv", "@z388z", "@EricLDaugh"], "support": "Republican"}
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "admiration",
#   "mentioned": [
#     "mjfree",
#     "ElonMusk",
#     "realDonaldTrump"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["rekharanibsp"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "caution",
#   "mentioned": ["Morning_Joe", "neal"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "relief",
#   "mentioned": ["MaxFlugrath"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "sarcasm",
#   "mentioned": ["MarioNawfal"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "satisfaction",
#   "mentioned": ["Kamala Harris", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "confusion",
#   "mentioned": ["Morning_Joe"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["LauraLoomer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["DanRShafer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "hopeful",
#   "mentioned": ["Kasparov63", "Harris", "Bret"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "disagreement",
#   "mentioned": ["RFK", "Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["OpenSecretsDC"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "supportive",
#   "mentioned": ["MikeNellis", "KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["VigilantFox"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indecision",
#   "mentioned": ["TristanSnell"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "serious",
#   "mentioned": ["MarkHamill", "senecaprojectus"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "assertive",
#   "mentioned": ["MTGrepp"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "caution",
#   "mentioned": ["SimonWDC", "Polymarket", "Elon"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Donald Trump", "McfarlaneGlenda"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Real_RobN"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "defiance",
#   "mentioned": ["Barack Obama", "WesleyHuntTX"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "confusion",
#   "mentioned": ["Morning_Joe"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "nostalgia",
#   "mentioned": ["LouDPhillips"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["FBI", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "fear",
#   "mentioned": ["Kamala"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifferent",
#   "mentioned": ["Bupendra Hooda", "Sharad Pawar"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "surprise",
#   "mentioned": ["PanditSaibpal", "Abhay Dubey"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["MichelleObama", "WhenWeAllVote"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["JesseBWatters", "KamalaHarris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["ChatGPT"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["@whatifalthist", "@Timcast"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["DonMiami3"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "humiliation",
#   "mentioned": ["Donald Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@C_Farthammer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["RealMattCouch", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["@joshtheobald3"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["AndrewPatriot_"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["LongTimeHistory"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["BillieJeanKing"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "admiration",
#   "mentioned": [
#     "Heath Mayo",
#     "Colin Allred",
#     "Ted Cruz"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@ZiyaMadlakes", "@MbuyiseniNdlozi", "@Julius_S_Malema"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "supportive",
#   "mentioned": ["MikeNellis", "KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Michelle Obama"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["GuntherEagleman"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["@realDonaldTrump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["MargieVotes"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [
#     "glassfire77",
#     "0xMikado"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["BrendanKeefe"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "mocking",
#   "mentioned": ["@scrowder"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["SenJohnKennedy", "Biden-Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["hodgetwins", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "hopeful",
#   "mentioned": ["CristusVictor"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "none",
#   "mentioned": ["FrankLuntz", "NPR", "Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["NickJFuentes", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "inclusive",
#   "mentioned": ["ScottPresler", "RFK Jr."],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["joncoopertweets"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "mockery",
#   "mentioned": ["Jimmy", "Trump", "Carter"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["NewsArenaIndia", "NCP", "Sharad Pawar"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "frustration",
#   "mentioned": ["MTGrepp"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anxious",
#   "mentioned": ["@django"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "Starboy2079"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["@christianboutin", "@scrowder"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "satisfaction",
#   "mentioned": ["@OccupyDemocrats"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["MJTruthUltra"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["hodgetwins", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["GuntherEagleman"],
#   "support": "unknown"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["ecomarxi"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["WarrenCoDemsOH"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["JakeLangJ6", "Youngkin"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["@PettyLupone", "@Bobbysworld2021"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["PpollingNumbers", "Trump", "Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["FrankLuntz", "NPR", "Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "speculative",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["newrepublic", "Rasmussen Reports", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Trump", "FBI"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "seriousness",
#   "mentioned": ["BradBeauregardJ"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "seriousness",
#   "mentioned": ["BradBeauregardJ"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determined",
#   "mentioned": ["levparnas", "rea"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["nancyd1957", "sdduba"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["ecomarxi"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Joe Rogan", "Kamala Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": [
#     "@I_Am_Legion_73",
#     "@wires44",
#     "@IsabellaMDeLuca"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "warning",
#   "mentioned": ["7im", "Stanley"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "nostalgia",
#   "mentioned": ["AngelaBelcamino", "Trump", "Biden"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["PeterHRatcliffe", "CPC_HQ", "Pierre Poilievre", "JustinTrudeau"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["theprofsrecord"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "dislike",
#   "mentioned": ["SebGorka"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["BrandyZadrozny"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "@DougWahl1"
#   ],
#   "support": "Republican"
# }

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} to identify 10 topics, 
                                  Do not wrap the json codes in JSON markers """},
        {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter} "}]
print(openai_help(messages))
# Out:
# {
#   "topics": [
#     "Election Integrity and Fraud Allegations",
#     "Voting Methods and Accessibility",
#     "Political Campaigns and Strategies",
#     "Media Influence and Election Coverage",
#     "Legal and Judicial Actions Related to Elections",
#     "Political Figures and Their Influence",
#     "Public Sentiment and Voter Engagement",
#     "Election Predictions and Market Reactions",
#     "International Influence and Relations",
#     "Social Media and Misinformation"
#   ]
# }

# %% [markdown]
# ### Expanding with multiple prompts
# - Identify which party receives majority supports
# - Provide contexts in the system message
# - Create a chatbot to answer users’ inquiry

# %%
analysis_result = []
from tqdm import tqdm
for tweet in tqdm(tweet_data):
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a singple word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    analysis_result.append(openai_help(messages))
# Out:
# 100%|██████████| 200/200 [03:22<00:00,  1.01s/it]

# %%
print(analysis_result)
# Out:
# ['{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Lucas_FCGB"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "suspicion",\n  "mentioned": ["VigilantFox"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\n  "mentioned": ["dYdX", "Trump"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["@CentristMadness"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "caution",\n  "mentioned": ["Craptld2kids"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["whstancil"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Rep. Mark Pocan", "StephMillerShow"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "positive",\n  "emotion": "motivated",\n  "mentioned": ["KamalaHarris"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anticipation",\n  "mentioned": ["argosaki"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Donald Trump"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "skepticism",\n  "mentioned": ["@Real_RobN"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["TristanSnell"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "disapproval",\n  "mentioned": ["Trump", "Kamala"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "determination",\n  "mentioned": ["mjfree"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": [],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["BretBaier"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "determination",\n  "mentioned": ["ssecijak"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "skepticism",\n  "mentioned": ["PATRICKHENRY97"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "determination",\n  "mentioned": ["Conservative_BC"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["TristanSnell"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "disdain",\n  "mentioned": ["Mike Johnson", "Trump"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anticipation",\n  "mentioned": ["hodgetwins", "Trump"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": ["Douglas Emhoff"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "positive",\n  "emotion": "excitement",\n  "mentioned": ["Trump"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "concern",\n  "mentioned": ["michaelsbarajas"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": [\n    "Abbas Alawieh"\n  ],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["TristanSnell"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": ["ghn_news"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["JoyceWhiteVance"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "concern",\n  "mentioned": [\n    "BrandtRobinson",\n    "TheClassicPhil"\n  ],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "skepticism",\n  "mentioned": ["Joe Rogan", "Kamala Harris"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["Lt. Gov. Mark Robinson"], ...

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet analysis reuslt delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} count the number of tweets that support Democratic and Republican;
                                        step 2 {delimiter} identify the common sentiments and emotoions to each mentioned people;
                                        step 3 {delimiter} organize the result in a json document with keys <Democratic count>, <Republican count>, <people name>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{analysis_result}{delimiter} "}]
analysis_summary = openai_help(messages)
print(analysis_summary)
# Out:
# {
#   "Democratic count": 28,
#   "Republican count": 54,
#   "people name": {
#     "Democratic": {
#       "common sentiments": ["negative", "neutral", "positive"],
#       "common emotions": ["frustration", "concern", "informative", "admiration", "supportive"]
#     },
#     "Republican": {
#       "common sentiments": ["negative", "neutral", "positive"],
#       "common emotions": ["frustration", "anger", "informative", "skepticism", "anticipation"]
#     }
#   }
# }

# %% [markdown]
# ## Create a chatbot

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

chat_history = [

{"role": "system", "content": f"""you are a chabot answer user questions based on the tweets,
                                {delimiter}{tweet_data}{delimiter}, 
                                if user mentioned a people name in the {delimiter}{analysis_summary}{delimiter} people field,report the corresponding sentiment and emotion,
                            
                            """}
]

def chatbot(prompt):

    chat_history.append({"role": "user", "content": prompt})

    response = client.chat.completions.create(
        model=model,  # Use the model you prefer
        messages=chat_history
    )

    reply = response.choices[0].message.content

    chat_history.append({"role": "assistant", "content": reply})
    
    return reply

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break
    reply = chatbot(user_input)
    print(f"Chatbot: {reply}")

# %% [markdown]
# ## Reference
# - Isa Fulford and Andrew Ng. n.d.-a. *“Building Systems with the ChatGPT API.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/building-systems-with-chatgpt/.
# - ———. n.d.-b. *“ChatGPT Prompt Engineering for Developers.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/.
# - OpenAI. n.d. *“OpenAI Documents.”* OpenAI. Accessed October 18, 2024. https://platform.openai.com.
